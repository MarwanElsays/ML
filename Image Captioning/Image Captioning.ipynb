# %%
import pandas as pd
import PIL.Image
# import torch
import numpy as np
import keras
import re

import tensorflow as tf

# %% [markdown]
# # Load Images & Captions
# • Load, resize and normalize the images to a suitable format that can be efficiently
# processed by the CNN model.\
# • You should choose a standard size and normalization suitable for your CNN
# model.

# %%
captions_file_path = "data/captions.txt"
captions = pd.read_csv(captions_file_path)
captions.head()
# Out:
#                        image  \
# 0  1000268201_693b08cb0e.jpg
# 1  1000268201_693b08cb0e.jpg
# 2  1000268201_693b08cb0e.jpg
# 3  1000268201_693b08cb0e.jpg
# 4  1000268201_693b08cb0e.jpg
#
#                                              caption
# 0  A child in a pink dress is climbing up a set o...
# 1              A girl going into a wooden building .
# 2   A little girl climbing into a wooden playhouse .
# 3  A little girl climbing the stairs to her playh...
# 4  A little girl in a pink dress going into a woo...

# %%
def load_next_batch(images_path, captions, batch_size):
    for i in range(0, captions.unique().size, batch_size):
        batch = np.zeros((min(batch_size, captions.unique().size - i), 224, 224, 3), dtype=np.float64)
        for j in range(min(batch_size, captions.unique().size - i)):
            image_name = captions.unique()[i + j]
            image = PIL.Image.open(images_path + image_name)
            image = image.resize((224, 224))
            image = np.array(image, dtype=np.float64)
            image /= 255.0
            batch[j] = image

        yield batch

# %%
images_path = "./data/Images/"
batch_generator = load_next_batch(images_path, captions['image'], 1000)

for batch in batch_generator:
    print(batch.shape)
# Out:
# (1000, 224, 224, 3)
# (1000, 224, 224, 3)
# (1000, 224, 224, 3)
# (1000, 224, 224, 3)
# (1000, 224, 224, 3)
# (1000, 224, 224, 3)
# (1000, 224, 224, 3)
# (1000, 224, 224, 3)
# (91, 224, 224, 3)

# %% [markdown]
# # Preprocessing Captions for RNN

# %% [markdown]
# ## Normalising & Processing Captions

# %%
processed_captions = captions['caption'].apply(lambda x: x.lower())                    # put into lower case
processed_captions = processed_captions.apply(lambda x: re.sub(r"[^A-Za-z ]", "", x))  # remove non-alphabetic and non-space characters
processed_captions = processed_captions.apply(lambda x: re.sub(r" +", " ", x))         # remove multiple spaces
processed_captions = processed_captions.apply(lambda x: x.strip())                     # remove leading and trailing spaces

# remove single character words except for 'a' in the middle or start of sentence
processed_captions = processed_captions.apply(lambda x: re.sub(r" [^a] ", " ", x))
processed_captions = processed_captions.apply(lambda x: re.sub(r"(^[^a] | .$)", "", x))

processed_captions = "begintag " + processed_captions + " endtag"

processed_captions
# Out:
# 0        begintag a child in a pink dress is climbing u...
# 1        begintag a girl going into a wooden building e...
# 2        begintag a little girl climbing into a wooden ...
# 3        begintag a little girl climbing the stairs to ...
# 4        begintag a little girl in a pink dress going i...
#                                ...
# 40450    begintag a man in a pink shirt climbs a rock f...
# 40451    begintag a man is rock climbing high in the ai...
# 40452    begintag a person in a red shirt climbing up a...
# 40453        begintag a rock climber in a red shirt endtag
# 40454    begintag a rock climber practices on a rock cl...
# Name: caption, Length: 40455, dtype: object

# %% [markdown]
# ## Tokenize Captions & Build Vocabulary

# %%
tokenizer = keras.preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(processed_captions)

sequences = tokenizer.texts_to_sequences(processed_captions)

import functools
max_length = functools.reduce(lambda x, maximum: max(maximum, x), map(len, sequences))
del functools

sequences = keras.preprocessing.sequence.pad_sequences(sequences, max_length, padding='post')

sequences.shape
# Out:
# (40455, 37)

# %% [markdown]
# ## Write Token Indices Into a JSON File to View

# %%
import json

with open('word_index.json', 'w') as json_file:
    json.dump(tokenizer.word_index, json_file)

# %% [markdown]
# # Preparing Output Labels

# %%
next_word = np.zeros((sequences.shape[0], sequences.shape[1] - 1))

for i in range(sequences.shape[0]):
    for j in range(1, sequences.shape[1]):
        next_word[i][j - 1] = sequences[i][j]

# %%
resnet = keras.applications.resnet_v2.ResNet50V2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# do something here with the top layers of the model

images_path = "./data/Images/"
resnet.compile(loss='categorical_crossentropy')
batch = load_next_batch(images_path, captions['image'], 200).__next__()

# %%
prediction: np.ndarray = resnet.predict(batch)

prediction.nonzero()
# Out:
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001D3541E8860> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step

# %%
image_index = 1

indices = prediction[image_index].argsort()
indices[-5:]

keras.applications.resnet.decode_predictions(prediction, top=5)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 2us/step
# [[('n03467068', 'guillotine', 0.858231),
#   ('n03776460', 'mobile_home', 0.02827406),
#   ('n03899768', 'patio', 0.026914496),
#   ('n03697007', 'lumbermill', 0.01383134),
#   ('n02727426', 'apiary', 0.009180675)],
#  [('n02087046', 'toy_terrier', 0.31183186),
#   ('n02091032', 'Italian_greyhound', 0.26057705),
#   ('n02089867', 'Walker_hound', 0.1668409),
#   ('n02100236', 'German_short-haired_pointer', 0.102685325),
#   ('n02096585', 'Boston_bull', 0.05993147)],
#  [('n04026417', 'purse', 0.30360505),
#   ('n03709823', 'mailbag', 0.09338272),
#   ('n02110958', 'pug', 0.0662199),
#   ('n02085620', 'Chihuahua', 0.051686347),
#   ('n04398044', 'teapot', 0.045142654)],
#  [('n02087046', 'toy_terrier', 0.9063482),
#   ('n02085620', 'Chihuahua', 0.062341396),
#   ('n02096585', 'Boston_bull', 0.02767644),
#   ('n02110806', 'basenji', 0.0016489134),
#   ('n02113186', 'Cardigan', 0.0007351666)],
#  [('n09835506', 'ballplayer', 0.20567855),
#   ('n03124170', 'cowboy_hat', 0.15766764),
#   ('n03763968', 'military_uniform', 0.086610205),
#   ('n04259630', 'sombrero', 0.067896396),
#   ('n02787622', 'banjo', 0.024662226)],
#  [('n03733131', 'maypole', 0.44377133),
#   ('n03888605', 'parallel_bars', 0.2725252),
#   ('n01981276', 'king_crab', 0.06508707),
#   ('n04613696', 'yurt', 0.045721732),
#   ('n03535780', 'horizontal_bar', 0.032858625)],
#  [('n02102040', 'English_springer', 0.83029383),
#   ('n02106166', 'Border_collie', 0.078043796),
#   ('n02110185', 'Siberian_husky', 0.028022978),
#   ('n02096585', 'Boston_bull', 0.017782109),
#   ('n02088364', 'beagle', 0.0149173625)],
#  [('n02099712', 'Labrador_retriever', 0.29566756),
#   ('n02092339', 'Weimaraner', 0.18563893),
#   ('n02110341', 'dalmatian', 0.123049736),
#   ('n02108089', 'boxer', 0.106016345),
#   ('n02110958', 'pug', 0.061837193)],
#  [('n04507155', 'umbrella', 0.32670236),
#   ('n04458633', 'totem_pole', 0.11813546),
#   ('n03594734', 'jean', 0.06472869),
#   ('n04371774', 'swing', 0.05490138),
#   ('n03781244', 'monastery', 0.02547767)],
#  [('n02105412', 'kelpie', 0.3458893),
#   ('n02116738', 'African_hunting_dog', 0.2754944),
#   ('n02088632', 'bluetick', 0.19472088),
#   ('n02113186', 'Cardigan', 0.12273188),
#   ('n02106662', 'German_shepherd', 0.014354773)],
#  [('n02091134', 'whippet', 0.8956752),
#   ('n02090622', 'borzoi', 0.057674177),
#   ('n02091831', 'Saluki', 0.028919253),
#   ('n02091244', 'Ibizan_hound', 0.005731052),
#   ('n03218198', 'dogsled', 0.003101691)],
#  [('n04228054', 'ski', 0.9988104),
#   ('n04229816', 'ski_mask', 0.00020417705),
#   ('n02804610', 'bassoon', 0.00019521655),
#   ('n03141823', 'crutch', 9.611329e-05),
#   ('n04208210', 'shovel', 8.2843304e-05)],
#  [('n03814906', 'necklace', 0.5126961),
#   ('n04371774', 'swing', 0.09782914),
#   ('n09246464', 'cliff', 0.055197738),
#   ('n03770439', 'miniskirt', 0.050044205),
#   ('n03485794', 'handkerchief', 0.01838345)],
#  [('n02486410', 'baboon', 0.3450372),
#   ('n03134739', 'croquet_ball', 0.16861103),
#   ('n02105162', 'malinois', 0.09057284),
#   ('n01877812', 'wallaby', 0.05331205),
#   ('n02099849', 'Chesapeake_Bay_retriever', 0.030644562)],
#  [('n02091134', 'whippet', 0.37355724),
#   ('n02090622', 'borzoi', 0.32929546),
#   ('n02091244', 'Ibizan_hound', 0.25773346),
#   ('n02091831', 'Saluki', 0.03667894),
#   ('n02109047', 'Great_Dane', 0.0013457104)],
#  [('n02091244', 'Ibizan_hound', 0.2631502),
#   ('n09835506', 'ballplayer', 0.13965209),
#   ('n02087046', 'toy_terrier', 0.11665843),
#   ('n02009912', 'American_egret', 0.09465225),
#   ('n02089973', 'English_foxhound', 0.08207006)],
#  [('n03873416', 'paddle', 0.46124834),
#   ('n01860187', 'black_swan', 0.16769174),
#   ('n01855672', 'goose', 0.124020584),
#   ('n09332890', 'lakeside', 0.031575177),
#   ('n03495258', 'harp', 0.02015901)],
#  [('n04296562', 'stage', 0.0885055),
#   ('n04356056', 'sunglasses', 0.08764368),
#   ('n03467068', 'guillotine', 0.058624677),
#   ('n03495258', 'harp', 0.05101902),
#   ('n04355933', 'sunglass', 0.04726827)],
#  [('n02099267', 'flat-coated_retriever', 0.8281428),
#   ('n02099712', 'Labrador_retriever', 0.123282045),
#   ('n02092339', 'Weimaraner', 0.010546385),
#   ('n02099429', 'curly-coated_retriever', 0.010470352),
#   ('n02100236', 'German_short-haired_pointer', 0.004135408)],
#  [('n04252225', 'snowplow', 0.5592179),
#   ('n09421951', 'sandbar', 0.0699687),
#   ('n04019541', 'puck', 0.04019748),
#   ('n04228054', 'ski', 0.032476865),
#   ('n04606251', 'wreck', 0.022543661)],
#  [('n02110806', 'basenji', 0.99564385),
#   ('n02091244', 'Ibizan_hound', 0.0032383215),
#   ('n02115641', 'dingo', 0.00028242782),
#   ('n02091032', 'Italian_greyhound', 0.00025469283),
#   ('n02085620', 'Chihuahua', 0.00022251192)],
#  [('n04228054', 'ski', 0.481511),
#   ('n04371774', 'swing', 0.27762538),
#   ('n04208210', 'shovel', 0.15063818),
#   ('n04067472', 'reel', 0.02852416),
#   ('n03000684', 'chain_saw', 0.015723735)],
#  [('n02099712', 'Labrador_retriever', 0.841866),
#   ('n02099267', 'flat-coated_retriever', 0.12381244),
#   ('n02099429', 'curly-coated_retriever', 0.023142671),
#   ('n02100236', 'German_short-haired_pointer', 0.0064048413),
#   ('n02099849', 'Chesapeake_Bay_retriever', 0.0027512535)],
#  [('n02951358', 'canoe', 0.8651414),
#   ('n03873416', 'paddle', 0.092372246),
#   ('n04273569', 'speedboat', 0.04025797),
#   ('n03662601', 'lifeboat', 0.00037843589),
#   ('n02704792', 'amphibian', 0.00022335864)],
#  [('n02099712', 'Labrador_retriever', 0.3707649),
#   ('n02099849', 'Chesapeake_Bay_retriever', 0.2045774),
#   ('n02092339', 'Weimaraner', 0.18107349),
#   ('n02100236', 'German_short-haired_pointer', 0.16685279),
#   ('n02099267', 'flat-coated_retriever', 0.032850467)],
#  [('n02906734', 'broom', 0.7016863),
#   ('n04201297', 'shoji', 0.08283571),
#   ('n04019541', 'puck', 0.042334154),
#   ('n01748264', 'Indian_cobra', 0.021563832),
#   ('n04579432', 'whistle', 0.011807522)],
#  [('n03532672', 'hook', 0.34687427),
#   ('n03773504', 'missile', 0.24833074),
#   ('n04008634', 'projectile', 0.21179645),
#   ('n03126707', 'crane', 0.06862274),
#   ('n04552348', 'warplane', 0.016309742)],
#  [('n04606251', 'wreck', 0.4044118),
#   ('n03218198', 'dogsled', 0.18990025),
#   ('n04228054', 'ski', 0.09286597),
#   ('n09421951', 'sandbar', 0.084703766),
#   ('n04612504', 'yawl', 0.032661185)],
#  [('n02437616', 'llama', 0.5162932),
#   ('n02415577', 'bighorn', 0.19804315),
#   ('n02417914', 'ibex', 0.054158866),
#   ('n02091244', 'Ibizan_hound', 0.039400514),
#   ('n02114855', 'coyote', 0.039299306)],
#  [('n02825657', 'bell_cote', 0.5244159),
#   ('n03355925', 'flagpole', 0.072167106),
#   ('n02930766', 'cab', 0.05602995),
#   ('n03837869', 'obelisk', 0.029367605),
#   ('n03903868', 'pedestal', 0.028007587)],
#  [('n03840681', 'ocarina', 0.7101352),
#   ('n13133613', 'ear', 0.1864871),
#   ('n04579432', 'whistle', 0.028766952),
#   ('n07615774', 'ice_lolly', 0.024640193),
#   ('n12144580', 'corn', 0.018513422)],
#  [('n09193705', 'alp', 0.9778306),
#   ('n09468604', 'valley', 0.021257319),
#   ('n09332890', 'lakeside', 0.00031370923),
#   ('n09246464', 'cliff', 0.00015316636),
#   ('n03792972', 'mountain_tent', 0.00014914201)],
#  [('n02951358', 'canoe', 0.5917948),
#   ('n03873416', 'paddle', 0.11697099),
#   ('n03444034', 'go-kart', 0.10804233),
#   ('n02860847', 'bobsled', 0.101357765),
#   ('n04462240', 'toyshop', 0.04783735)],
#  [('n03141823', 'crutch', 0.48719895),
#   ('n02992529', 'cellular_telephone', 0.25074068),
#   ('n04317175', 'stethoscope', 0.11932153),
#   ('n03868863', 'oxygen_mask', 0.035356883),
#   ('n03902125', 'pay-phone', 0.018758614)],
#  [('n04404412', 'television', 0.69804245),
#   ('n04152593', 'screen', 0.29046556),
#   ('n03782006', 'monitor', 0.010398095),
#   ('n03180011', 'desktop_computer', 0.0005244708),
#   ('n04243546', 'slot', 0.00046719346)],
#  [('n09428293', 'seashore', 0.67849267),
#   ('n09421951', 'sandbar', 0.1067796),
#   ('n02894605', 'breakwater', 0.09453789),
#   ('n09332890', 'lakeside', 0.051818058),
#   ('n04371430', 'swimming_trunks', 0.01114039)],
#  [('n04553703', 'washbasin', 0.17982483),
#   ('n02791270', 'barbershop', 0.13465972),
#   ('n03483316', 'hand_blower', 0.072133884),
#   ('n04509417', 'unicycle', 0.04386503),
#   ('n04482393', 'tricycle', 0.04247688)],
#  [('n03873416', 'paddle', 0.6831852),
#   ('n02837789', 'bikini', 0.24518955),
#   ('n03710721', 'maillot', 0.014382074),
#   ('n04371430', 'swimming_trunks', 0.013241214),
#   ('n04251144', 'snorkel', 0.009330814)],
#  [('n04251144', 'snorkel', 0.86651844),
#   ('n02837789', 'bikini', 0.04001364),
#   ('n04039381', 'racket', 0.026196677),
#   ('n04371430', 'swimming_trunks', 0.023070736),
#   ('n03873416', 'paddle', 0.008437102)],
#  [('n04209133', 'shower_cap', 0.3445464),
#   ('n03483316', 'hand_blower', 0.25818482),
#   ('n04584207', 'wig', 0.04803825),
#   ('n03485794', 'handkerchief', 0.020677801),
#   ('n03958227', 'plastic_bag', 0.020153593)],
#  [('n02788148', 'bannister', 0.32632414),
#   ('n03467068', 'guillotine', 0.28924584),
#   ('n04005630', 'prison', 0.07727492),
#   ('n03733131', 'maypole', 0.064363286),
#   ('n09229709', 'bubble', 0.031744294)],
#  [('n02437312', 'Arabian_camel', 0.3102759),
#   ('n03538406', 'horse_cart', 0.24183908),
#   ('n02389026', 'sorrel', 0.06861029),
#   ('n02090379', 'redbone', 0.027018894),
#   ('n02087394', 'Rhodesian_ridgeback', 0.025314493)],
#  [('n04243546', 'slot', 0.18564759),
#   ('n03255030', 'dumbbell', 0.074379764),
#   ('n03770679', 'minivan', 0.0614662),
#   ('n04560804', 'water_jug', 0.058770295),
#   ('n04371774', 'swing', 0.044825975)],
#  [('n13133613', 'ear', 0.2746883),
#   ('n02666196', 'abacus', 0.16765052),
#   ('n03026506', 'Christmas_stocking', 0.13966401),
#   ('n12144580', 'corn', 0.11578895),
#   ('n02786058', 'Band_Aid', 0.09428104)],
#  [('n02105162', 'malinois', 0.9797196),
#   ('n02108089', 'boxer', 0.007672933),
#   ('n02115641', 'dingo', 0.003761511),
#   ('n02119022', 'red_fox', 0.0020361228),
#   ('n02108915', 'French_bulldog', 0.0014698828)],
#  [('n04604644', 'worm_fence', 0.5422483),
#   ('n03697007', 'lumbermill', 0.11705237),
#   ('n03891251', 'park_bench', 0.103644036),
#   ('n02071294', 'killer_whale', 0.03226218),
#   ('n03535780', 'horizontal_bar', 0.013381672)],
#  [('n02977058', 'cash_machine', 0.41977185),
#   ('n04239074', 'sliding_door', 0.35427403),
#   ('n04443257', 'tobacco_shop', 0.01373443),
#   ('n04501370', 'turnstile', 0.013116551),
#   ('n03425413', 'gas_pump', 0.012685964)],
#  [('n02086646', 'Blenheim_spaniel', 0.4263569),
#   ('n02110341', 'dalmatian', 0.1815355),
#   ('n02085620', 'Chihuahua', 0.17602694),
#   ('n02113186', 'Cardigan', 0.07956426),
#   ('n02102177', 'Welsh_springer_spaniel', 0.047761843)],
#  [('n04371430', 'swimming_trunks', 0.98999816),
#   ('n03188531', 'diaper', 0.005612721),
#   ('n04136333', 'sarong', 0.0022979355),
#   ('n02837789', 'bikini', 0.0006670342),
#   ('n02807133', 'bathing_cap', 0.0004836265)],
#  [('n09193705', 'alp', 0.9752617),
#   ('n04252077', 'snowmobile', 0.006115394),
#   ('n09468604', 'valley', 0.0054250304),
#   ('n04228054', 'ski', 0.002947124),
#   ('n09428293', 'seashore', 0.0016347548)],
#  [('n02106166', 'Border_collie', 0.46031407),
#   ('n02091831', 'Saluki', 0.22882386),
#   ('n02107908', 'Appenzeller', 0.13105531),
#   ('n02108000', 'EntleBucher', 0.105283916),
#   ('n02106030', 'collie', 0.03345432)],
#  [('n03770679', 'minivan', 0.72575426),
#   ('n03417042', 'garbage_truck', 0.08475493),
#   ('n02930766', 'cab', 0.034469727),
#   ('n03425413', 'gas_pump', 0.015664777),
#   ('n02965783', 'car_mirror', 0.011860189)],
#  [('n02111277', 'Newfoundland', 0.39666185),
#   ('n02102040', 'English_springer', 0.22722286),
#   ('n02107142', 'Doberman', 0.098942995),
#   ('n02106550', 'Rottweiler', 0.05686387),
#   ('n02108089', 'boxer', 0.04015885)],
#  [('n02106166', 'Border_collie', 0.7577725),
#   ('n02102040', 'English_springer', 0.113609895),
#   ('n02106030', 'collie', 0.045792542),
#   ('n02090622', 'borzoi', 0.020896565),
#   ('n02110185', 'Siberian_husky', 0.018734293)],
#  [('n02782093', 'balloon', 0.9929939),
#   ('n02807133', 'bathing_cap', 0.00083572295),
#   ('n02692877', 'airship', 0.0005745705),
#   ('n03888257', 'parachute', 0.0005352293),
#   ('n04356056', 'sunglasses', 0.00047780827)],
#  [('n03792782', 'mountain_bike', 0.99040306),
#   ('n04509417', 'unicycle', 0.0075067747),
#   ('n02835271', 'bicycle-built-for-two', 0.0019260725),
#   ('n03127747', 'crash_helmet', 8.566998e-05),
#   ('n04482393', 'tricycle', 3.4513298e-05)],
#  [('n03447447', 'gondola', 0.2751175),
#   ('n04081281', 'restaurant', 0.10991845),
#   ('n03721384', 'marimba', 0.069183424),
#   ('n03868242', 'oxcart', 0.052895095),
#   ('n04296562', 'stage', 0.048118126)],
#  [('n02107142', 'Doberman', 0.48459908),
#   ('n02107312', 'miniature_pinscher', 0.23903117),
#   ('n02089078', 'black-and-tan_coonhound', 0.08489197),
#   ('n02105412', 'kelpie', 0.07758675),
#   ('n02106550', 'Rottweiler', 0.030667499)],
#  [('n01943899', 'conch', 0.09948476),
#   ('n04507155', 'umbrella', 0.07559965),
#   ('n01847000', 'drake', 0.05744597),
#   ('n07880968', 'burrito', 0.054005165),
#   ('n02747177', 'ashcan', 0.051444467)],
#  [('n07615774', 'ice_lolly', 0.9833233),
#   ('n04560804', 'water_jug', 0.008419476),
#   ('n03873416', 'paddle', 0.0020564178),
#   ('n04251144', 'snorkel', 0.00092287274),
#   ('n04493381', 'tub', 0.00092112296)],
#  [('n01614925', 'bald_eagle', 0.68770754),
#   ('n01608432', 'kite', 0.26466778),
#   ('n02058221', 'albatross', 0.014818841),
#   ('n02051845', 'pelican', 0.0106415935),
#   ('n02002724', 'black_stork', 0.0053314357)],
#  [('n03814639', 'neck_brace', 0.62057346),
#   ('n03188531', 'diaper', 0.08586955),
#   ('n02777292', 'balance_beam', 0.031155877),
#   ('n04371430', 'swimming_trunks', 0.024547175),
#   ('n03535780', 'horizontal_bar', 0.023130603)],
#  [('n02389026', 'sorrel', 0.9938652),
#   ('n02437312', 'Arabian_camel', 0.0041213916),
#   ('n02422106', 'hartebeest', 0.00067973236),
#   ('n02408429', 'water_buffalo', 0.00025276482),
#   ('n03967562', 'plow', 0.00025030505)],
#  [('n02389026', 'sorrel', 0.63017356),
#   ('n02105855', 'Shetland_sheepdog', 0.22964966),
#   ('n02087394', 'Rhodesian_ridgeback', 0.035909235),
#   ('n02108089', 'boxer', 0.034372017),
#   ('n02403003', 'ox', 0.009394963)],
#  [('n04371430', 'swimming_trunks', 0.27976015),
#   ('n10148035', 'groom', 0.12413866),
#   ('n03642806', 'laptop', 0.11460837),
#   ('n02727426', 'apiary', 0.09615821),
#   ('n03832673', 'notebook', 0.06759103)],
#  [('n02114548', 'white_wolf', 0.637184),
#   ('n02104029', 'kuvasz', 0.12766208),
#   ('n02111500', 'Great_Pyrenees', 0.08697274),
#   ('n02109961', 'Eskimo_dog', 0.06650509),
#   ('n02110185', 'Siberian_husky', 0.021397578)],
#  [('n03944341', 'pinwheel', 0.22792752),
#   ('n04371774', 'swing', 0.20468989),
#   ('n04371430', 'swimming_trunks', 0.098278224),
#   ('n02085620', 'Chihuahua', 0.047548044),
#   ('n03188531', 'diaper', 0.046876147)],
#  [('n04023962', 'punching_bag', 0.9985795),
#   ('n04507155', 'umbrella', 0.00045258526),
#   ('n03792972', 'mountain_tent', 0.0003974509),
#   ('n02782093', 'balloon', 0.000121429955),
#   ('n03888257', 'parachute', 9.904493e-05)],
#  [('n03649909', 'lawn_mower', 0.9934649),
#   ('n03444034', 'go-kart', 0.0051057613),
#   ('n04517823', 'vacuum', 0.00043610975),
#   ('n03000684', 'chain_saw', 0.00041529516),
#   ('n03445924', 'golfcart', 0.0002435878)],
#  [('n04456115', 'torch', 0.8732843),
#   ('n03770439', 'miniskirt', 0.04184224),
#   ('n04509417', 'unicycle', 0.015677048),
#   ('n02807133', 'bathing_cap', 0.011710511),
#   ('n03325584', 'feather_boa', 0.011163085)],
#  [('n04228054', 'ski', 0.97291744),
#   ('n04507155', 'umbrella', 0.007838836),
#   ('n04229816', 'ski_mask', 0.003921575),
#   ('n04208210', 'shovel', 0.002550273),
#   ('n03495258', 'harp', 0.0016959073)],
#  [('n09193705', 'alp', 0.66525716),
#   ('n04592741', 'wing', 0.09177488),
#   ('n04228054', 'ski', 0.058425527),
#   ('n03028079', 'church', 0.044361997),
#   ('n02793495', 'barn', 0.03645713)],
#  [('n02100877', 'Irish_setter', 0.9610235),
#   ('n02099601', 'golden_retriever', 0.013275397),
#   ('n02099267', 'flat-coated_retriever', 0.007942031),
#   ('n02091831', 'Saluki', 0.0028037108),
#   ('n02105412', 'kelpie', 0.002338106)],
#  [('n04501370', 'turnstile', 0.9275613),
#   ('n03933933', 'pier', 0.021948434),
#   ('n03888605', 'parallel_bars', 0.011444571),
#   ('n03240683', 'drilling_platform', 0.006900031),
#   ('n02788148', 'bannister', 0.0044353358)],
#  [('n02389026', 'sorrel', 0.84242636),
#   ('n02111129', 'Leonberg', 0.03152109),
#   ('n02088094', 'Afghan_hound', 0.021319332),
#   ('n02091831', 'Saluki', 0.020584712),
#   ('n02087394', 'Rhodesian_ridgeback', 0.013404133)],
#  [('n03538406', 'horse_cart', 0.9998474),
#   ('n03967562', 'plow', 0.00014455088),
#   ('n03868242', 'oxcart', 6.035903e-06),
#   ('n02389026', 'sorrel', 1.1755772e-06),
#   ('n03218198', 'dogsled', 4.5216203e-07)],
#  [('n01737021', 'water_snake', 0.6572229),
#   ('n09246464', 'cliff', 0.05963423),
#   ('n09468604', 'valley', 0.039232355),
#   ('n01873310', 'platypus', 0.016482607),
#   ('n04485082', 'tripod', 0.010146861)],
#  [('n10565667', 'scuba_diver', 0.15990503),
#   ('n03467068', 'guillotine', 0.07371066),
#   ('n09246464', 'cliff', 0.050831597),
#   ('n09256479', 'coral_reef', 0.032507148),
#   ('n10148035', 'groom', 0.030263737)],
#  [('n09472597', 'volcano', 0.45236093),
#   ('n04252077', 'snowmobile', 0.17646268),
#   ('n09193705', 'alp', 0.15728435),
#   ('n03792972', 'mountain_tent', 0.03438859),
#   ('n02704792', 'amphibian', 0.034291275)],
#  [('n04228054', 'ski', 0.12476941),
#   ('n03899768', 'patio', 0.07695901),
#   ('n04019541', 'puck', 0.07283901),
#   ('n03876231', 'paintbrush', 0.060379673),
#   ('n03290653', 'entertainment_center', 0.04213555)],
#  [('n02099601', 'golden_retriever', 0.91969603),
#   ('n02113023', 'Pembroke', 0.03488308),
#   ('n02093991', 'Irish_terrier', 0.016351335),
#   ('n02113186', 'Cardigan', 0.0072242655),
#   ('n02112137', 'chow', 0.004466904)],
#  [('n03388043', 'fountain', 1.0),
#   ('n03344393', 'fireboat', 6.32552e-09),
#   ('n02807133', 'bathing_cap', 1.8999757e-09),
#   ('n04371430', 'swimming_trunks', 1.7128091e-09),
#   ('n04371774', 'swing', 1.6501451e-09)],
#  [('n02113186', 'Cardigan', 0.99727505),
#   ('n02113023', 'Pembroke', 0.0024724787),
#   ('n02105855', 'Shetland_sheepdog', 0.00014911068),
#   ('n02110806', 'basenji', 6.590164e-05),
#   ('n02106166', 'Border_collie', 1.773223e-05)],
#  [('n02099601', 'golden_retriever', 0.61100394),
#   ('n02099712', 'Labrador_retriever', 0.26690415),
#   ('n02087394', 'Rhodesian_ridgeback', 0.04123287),
#   ('n02106662', 'German_shepherd', 0.030306121),
#   ('n02093754', 'Border_terrier', 0.010856854)],
#  [('n03710721', 'maillot', 0.5548085),
#   ('n02837789', 'bikini', 0.21846372),
#   ('n03710637', 'maillot', 0.17419173),
#   ('n04371430', 'swimming_trunks', 0.014311789),
#   ('n02788148', 'bannister', 0.00739185)],
#  [('n02090622', 'borzoi', 0.5799942),
#   ('n02091134', 'whippet', 0.09138388),
#   ('n02447366', 'badger', 0.0846061),
#   ('n02091032', 'Italian_greyhound', 0.06257867),
#   ('n02443114', 'polecat', 0.015836315)],
#  [('n04251144', 'snorkel', 0.5152921),
#   ('n02807133', 'bathing_cap', 0.26461548),
#   ('n04371430', 'swimming_trunks', 0.0745392),
#   ('n02777292', 'balance_beam', 0.021074334),
#   ('n03888605', 'parallel_bars', 0.020572623)],
#  [('n02108089', 'boxer', 0.40504932),
#   ('n02091134', 'whippet', 0.28531736),
#   ('n02110806', 'basenji', 0.16799437),
#   ('n02091032', 'Italian_greyhound', 0.03248447),
#   ('n02091244', 'Ibizan_hound', 0.026711743)],
#  [('n09246464', 'cliff', 0.9237423),
#   ('n04509417', 'unicycle', 0.030491881),
#   ('n02028035', 'redshank', 0.012852218),
#   ('n02002724', 'black_stork', 0.008293111),
#   ('n09193705', 'alp', 0.005956136)],
#  [('n04252077', 'snowmobile', 0.9998148),
#   ('n03873416', 'paddle', 0.000112888534),
#   ('n02951358', 'canoe', 5.502068e-05),
#   ('n12057211', "yellow_lady's_slipper", 2.5222432e-06),
#   ('n02860847', 'bobsled', 2.4599417e-06)],
#  [('n04252077', 'snowmobile', 0.9991856),
#   ('n02860847', 'bobsled', 0.00030799897),
#   ('n03662601', 'lifeboat', 0.00028989144),
#   ('n03873416', 'paddle', 4.026524e-05),
#   ('n03218198', 'dogsled', 2.7009712e-05)],
#  [('n03649909', 'lawn_mower', 0.49139994),
#   ('n03445924', 'golfcart', 0.19073579),
#   ('n03127747', 'crash_helmet', 0.063883066),
#   ('n04465501', 'tractor', 0.04602148),
#   ('n03967562', 'plow', 0.032235213)],
#  [('n03496892', 'harvester', 0.23395291),
#   ('n03649909', 'lawn_mower', 0.21766935),
#   ('n04465501', 'tractor', 0.14319022),
#   ('n03967562', 'plow', 0.12859185),
#   ('n04428191', 'thresher', 0.10645409)],
#  [('n04465501', 'tractor', 0.35259438),
#   ('n03496892', 'harvester', 0.34312367),
#   ('n03967562', 'plow', 0.09865914),
#   ('n03649909', 'lawn_mower', 0.07003198),
#   ('n04461696', 'tow_truck', 0.033137225)],
#  [('n03388043', 'fountain', 0.988181),
#   ('n04509417', 'unicycle', 0.0014254954),
#   ('n04019541', 'puck', 0.0009950175),
#   ('n09835506', 'ballplayer', 0.0008290535),
#   ('n03535780', 'horizontal_bar', 0.00080033566)],
#  [('n04371774', 'swing', 0.40575987),
#   ('n03733281', 'maze', 0.2817398),
#   ('n04540053', 'volleyball', 0.06635589),
#   ('n04254680', 'soccer_ball', 0.059577767),
#   ('n03733131', 'maypole', 0.048490856)],
#  [('n09229709', 'bubble', 0.4425599),
#   ('n04367480', 'swab', 0.11936093),
#   ('n15075141', 'toilet_tissue', 0.098983414),
#   ('n03876231', 'paintbrush', 0.07921053),
#   ('n03887697', 'paper_towel', 0.03158555)],
#  [('n04509417', 'unicycle', 0.7994791),
#   ('n03792782', 'mountain_bike', 0.1620116),
#   ('n02835271', 'bicycle-built-for-two', 0.038081083),
#   ('n09193705', 'alp', 0.00024708777),
#   ('n03785016', 'moped', 0.00010674639)],
#  [('n02099267', 'flat-coated_retriever', 0.8768485),
#   ('n02105412', 'kelpie', 0.05117044),
#   ('n02099712', 'Labrador_retriever', 0.030672543),
#   ('n02104365', 'schipperke', 0.01769439),
#   ('n02105056', 'groenendael', 0.0052949185)],
#  [('n03976467', 'Polaroid_camera', 0.8830674),
#   ('n02356798', 'fox_squirrel', 0.042566407),
#   ('n04009552', 'projector', 0.022872128),
#   ('n02965783', 'car_mirror', 0.015837168),
#   ('n04069434', 'reflex_camera', 0.011196249)],
#  [('n02091831', 'Saluki', 0.41196817),
#   ('n02090622', 'borzoi', 0.17875934),
#   ('n02106166', 'Border_collie', 0.08615275),
#   ('n02106030', 'collie', 0.049686946),
#   ('n02437616', 'llama', 0.047389556)],
#  [('n04326547', 'stone_wall', 0.34012926),
#   ('n04254680', 'soccer_ball', 0.18439727),
#   ('n04482393', 'tricycle', 0.065970436),
#   ('n03623198', 'knee_pad', 0.061855424),
#   ('n03720891', 'maraca', 0.053693406)],
#  [('n09246464', 'cliff', 0.31928453),
#   ('n09193705', 'alp', 0.22600085),
#   ('n04228054', 'ski', 0.17752902),
#   ('n04371430', 'swimming_trunks', 0.15578131),
#   ('n04509417', 'unicycle', 0.019373592)],
#  [('n09246464', 'cliff', 0.99129045),
#   ('n03042490', 'cliff_dwelling', 0.005881553),
#   ('n04067472', 'reel', 0.0012034023),
#   ('n04371774', 'swing', 0.00025475648),
#   ('n03372029', 'flute', 0.0002328645)],
#  [('n03792782', 'mountain_bike', 0.38022566),
#   ('n04251144', 'snorkel', 0.14231904),
#   ('n03127747', 'crash_helmet', 0.096242234),
#   ('n03444034', 'go-kart', 0.073769115),
#   ('n02807133', 'bathing_cap', 0.024471596)],
#  [('n01665541', 'leatherback_turtle', 0.5521248),
#   ('n02093859', 'Kerry_blue_terrier', 0.13529085),
#   ('n02097130', 'giant_schnauzer', 0.035716135),
#   ('n02102318', 'cocker_spaniel', 0.027495569),
#   ('n02317335', 'starfish', 0.023651948)],
#  [('n09428293', 'seashore', 0.3537894),
#   ('n09332890', 'lakeside', 0.22211394),
#   ('n02894605', 'breakwater', 0.1534548),
#   ('n09421951', 'sandbar', 0.1251109),
#   ('n01677366', 'common_iguana', 0.090877354)],
#  [('n01592084', 'chickadee', 0.9999993),
#   ('n01560419', 'bulbul', 3.981285e-07),
#   ('n02510455', 'giant_panda', 3.7598603e-08),
#   ('n01580077', 'jay', 2.1245217e-08),
#   ('n01601694', 'water_ouzel', 1.56953e-08)],
#  [('n02090379', 'redbone', 0.5924555),
#   ('n02087394', 'Rhodesian_ridgeback', 0.16522698),
#   ('n02091032', 'Italian_greyhound', 0.14878039),
#   ('n02107142', 'Doberman', 0.028630171),
#   ('n02100583', 'vizsla', 0.024457036)],
#  [('n04371430', 'swimming_trunks', 0.74434114),
#   ('n02837789', 'bikini', 0.05675448),
#   ('n03710637', 'maillot', 0.051150374),
#   ('n03710721', 'maillot', 0.042851236),
#   ('n04493381', 'tub', 0.03666739)],
#  [('n02325366', 'wood_rabbit', 0.71524966),
#   ('n02113023', 'Pembroke', 0.104555696),
#   ('n02113186', 'Cardigan', 0.098908305),
#   ('n02085620', 'Chihuahua', 0.068759866),
#   ('n02326432', 'hare', 0.003310703)],
#  [('n02107908', 'Appenzeller', 0.42958313),
#   ('n02107574', 'Greater_Swiss_Mountain_dog', 0.38612458),
#   ('n02108000', 'EntleBucher', 0.10041194),
#   ('n02090622', 'borzoi', 0.019210983),
#   ('n02091831', 'Saluki', 0.013127528)],
#  [('n04493381', 'tub', 0.21353495),
#   ('n01498041', 'stingray', 0.16681299),
#   ('n03710721', 'maillot', 0.12351762),
#   ('n02807133', 'bathing_cap', 0.1195353),
#   ('n02837789', 'bikini', 0.10903761)],
#  [('n02892767', 'brassiere', 0.22591862),
#   ('n02837789', 'bikini', 0.18721613),
#   ('n02777292', 'balance_beam', 0.1294431),
#   ('n03188531', 'diaper', 0.05843699),
#   ('n03710637', 'maillot', 0.037121847)],
#  [('n09421951', 'sandbar', 0.300165),
#   ('n04254680', 'soccer_ball', 0.18638024),
#   ('n04540053', 'volleyball', 0.17557576),
#   ('n09835506', 'ballplayer', 0.090458),
#   ('n04371430', 'swimming_trunks', 0.07725493)],
#  [('n01582220', 'magpie', 0.2038209),
#   ('n03792782', 'mountain_bike', 0.20061599),
#   ('n03888257', 'parachute', 0.13871174),
#   ('n01616318', 'vulture', 0.06528987),
#   ('n01795545', 'black_grouse', 0.042133525)],
#  [('n03630383', 'lab_coat', 0.22147532),
#   ('n04270147', 'spatula', 0.120628856),
#   ('n03887697', 'paper_towel', 0.11040797),
#   ('n03188531', 'diaper', 0.08193479),
#   ('n03958227', 'plastic_bag', 0.05145592)],
#  [('n03792782', 'mountain_bike', 0.2564286),
#   ('n04509417', 'unicycle', 0.16992822),
#   ('n03785016', 'moped', 0.15782884),
#   ('n02835271', 'bicycle-built-for-two', 0.08523473),
#   ('n04482393', 'tricycle', 0.06450378)],
#  [('n04251144', 'snorkel', 0.6330022),
#   ('n02088466', 'bloodhound', 0.22521839),
#   ('n03803284', 'muzzle', 0.10411188),
#   ('n02090379', 'redbone', 0.016483245),
#   ('n02108422', 'bull_mastiff', 0.0051841913)],
#  [('n01943899', 'conch', 0.7525392),
#   ('n10148035', 'groom', 0.067543924),
#   ('n01742172', 'boa_constrictor', 0.04820715),
#   ('n03720891', 'maraca', 0.020880474),
#   ('n03710637', 'maillot', 0.010999272)],
#  [('n02100583', 'vizsla', 0.9928598),
#   ('n02099849', 'Chesapeake_Bay_retriever', 0.005487329),
#   ('n02100236', 'German_short-haired_pointer', 0.0014910725),
#   ('n02092339', 'Weimaraner', 3.7187594e-05),
#   ('n02088238', 'basset', 3.334161e-05)],
#  [('n02115913', 'dhole', 0.5222906),
#   ('n02091244', 'Ibizan_hound', 0.109407075),
#   ('n02115641', 'dingo', 0.10284129),
#   ('n03388043', 'fountain', 0.09939907),
#   ('n02110806', 'basenji', 0.06704326)],
#  [('n02099712', 'Labrador_retriever', 0.103491224),
#   ('n02105412', 'kelpie', 0.08857236),
#   ('n02096585', 'Boston_bull', 0.085489556),
#   ('n09428293', 'seashore', 0.059748158),
#   ('n02099429', 'curly-coated_retriever', 0.047204908)],
#  [('n04228054', 'ski', 0.13986968),
#   ('n04019541', 'puck', 0.12398734),
#   ('n03594734', 'jean', 0.09433905),
#   ('n02777292', 'balance_beam', 0.057466533),
#   ('n03535780', 'horizontal_bar', 0.053223796)],
#  [('n02109525', 'Saint_Bernard', 0.9895806),
#   ('n02106166', 'Border_collie', 0.0024710912),
#   ('n02106030', 'collie', 0.0024118165),
#   ('n02107683', 'Bernese_mountain_dog', 0.0019111728),
#   ('n02113186', 'Cardigan', 0.0012827325)],
#  [('n04005630', 'prison', 0.7969216),
#   ('n04501370', 'turnstile', 0.064806044),
#   ('n04239074', 'sliding_door', 0.050960995),
#   ('n03899768', 'patio', 0.041144226),
#   ('n02966193', 'carousel', 0.008060821)],
#  [('n02804414', 'bassinet', 0.30596322),
#   ('n03534580', 'hoopskirt', 0.288493),
#   ('n03125729', 'cradle', 0.10824597),
#   ('n03866082', 'overskirt', 0.032796957),
#   ('n02841315', 'binoculars', 0.03255683)],
#  [('n03388549', 'four-poster', 0.40094304),
#   ('n04344873', 'studio_couch', 0.27816728),
#   ('n04550184', 'wardrobe', 0.054405786),
#   ('n04033995', 'quilt', 0.046744704),
#   ('n04235860', 'sleeping_bag', 0.02666035)],
#  [('n04228054', 'ski', 0.86085767),
#   ('n09193705', 'alp', 0.090373434),
#   ('n04252077', 'snowmobile', 0.03015634),
#   ('n02860847', 'bobsled', 0.0058816564),
#   ('n03792972', 'mountain_tent', 0.0024918984)],
#  [('n02791270', 'barbershop', 0.31404376),
#   ('n02871525', 'bookshop', 0.20676161),
#   ('n04443257', 'tobacco_shop', 0.13579284),
#   ('n02776631', 'bakery', 0.056871187),
#   ('n04456115', 'torch', 0.03581237)],
#  [('n03769881', 'minibus', 0.2825127),
#   ('n03796401', 'moving_van', 0.23579708),
#   ('n03770679', 'minivan', 0.22163723),
#   ('n04162706', 'seat_belt', 0.119645976),
#   ('n03670208', 'limousine', 0.0662478)],
#  [('n04275548', 'spider_web', 0.9089724),
#   ('n04366367', 'suspension_bridge', 0.089331836),
#   ('n03947888', 'pirate', 0.0010929091),
#   ('n01773797', 'garden_spider', 0.00013614289),
#   ('n01773157', 'black_and_gold_garden_spider', 8.112295e-05)],
#  [('n03417042', 'garbage_truck', 0.9999974),
#   ('n03796401', 'moving_van', 7.1973614e-07),
#   ('n02701002', 'ambulance', 3.5207276e-07),
#   ('n04428191', 'thresher', 3.164154e-07),
#   ('n03345487', 'fire_engine', 2.4592305e-07)],
#  [('n02807133', 'bathing_cap', 0.63979536),
#   ('n02869837', 'bonnet', 0.2305718),
#   ('n04209133', 'shower_cap', 0.05998225),
#   ('n03124170', 'cowboy_hat', 0.020989086),
#   ('n04584207', 'wig', 0.007210858)],
#  [('n02835271', 'bicycle-built-for-two', 0.43901932),
#   ('n04509417', 'unicycle', 0.2923646),
#   ('n03792782', 'mountain_bike', 0.265523),
#   ('n03599486', 'jinrikisha', 0.0018450757),
#   ('n04482393', 'tricycle', 0.0008433448)],
#  [('n02835271', 'bicycle-built-for-two', 0.46261826),
#   ('n04509417', 'unicycle', 0.28856578),
#   ('n03792782', 'mountain_bike', 0.14752434),
#   ('n03599486', 'jinrikisha', 0.05405232),
#   ('n04482393', 'tricycle', 0.041697472)],
#  [('n02835271', 'bicycle-built-for-two', 0.94191474),
#   ('n03792782', 'mountain_bike', 0.05180076),
#   ('n03127747', 'crash_helmet', 0.0023408264),
#   ('n03785016', 'moped', 0.0017722272),
#   ('n04509417', 'unicycle', 0.0012583704)],
#  [('n04371774', 'swing', 0.43025526),
#   ('n03617480', 'kimono', 0.07385471),
#   ('n03770439', 'miniskirt', 0.026832968),
#   ('n04456115', 'torch', 0.025899367),
#   ('n03733131', 'maypole', 0.024376001)],
#  [('n02687172', 'aircraft_carrier', 0.2319415),
#   ('n02835271', 'bicycle-built-for-two', 0.19231668),
#   ('n03599486', 'jinrikisha', 0.15953532),
#   ('n06874185', 'traffic_light', 0.1535501),
#   ('n02788148', 'bannister', 0.047479082)],
#  [('n03538406', 'horse_cart', 0.84789634),
#   ('n03868242', 'oxcart', 0.13415284),
#   ('n04204347', 'shopping_cart', 0.0065163537),
#   ('n03599486', 'jinrikisha', 0.0043981527),
#   ('n03891251', 'park_bench', 0.0018394457)],
#  [('n09229709', 'bubble', 0.99946946),
#   ('n03347037', 'fire_screen', 0.00018967899),
#   ('n03692522', 'loupe', 0.00014837486),
#   ('n03788365', 'mosquito_net', 2.9258512e-05),
#   ('n04039381', 'racket', 1.7338349e-05)],
#  [('n04371430', 'swimming_trunks', 0.6774537),
#   ('n01855032', 'red-breasted_merganser', 0.11840568),
#   ('n09421951', 'sandbar', 0.09788793),
#   ('n01833805', 'hummingbird', 0.024052083),
#   ('n02807133', 'bathing_cap', 0.014287976)],
#  [('n04118538', 'rugby_ball', 0.29796755),
#   ('n03379051', 'football_helmet', 0.14125787),
#   ('n04487394', 'trombone', 0.08717542),
#   ('n04192698', 'shield', 0.07388326),
#   ('n04254680', 'soccer_ball', 0.050913956)],
#  [('n04081281', 'restaurant', 0.92840487),
#   ('n02939185', 'caldron', 0.022376595),
#   ('n04311174', 'steel_drum', 0.01361839),
#   ('n04596742', 'wok', 0.007586993),
#   ('n03201208', 'dining_table', 0.0047108647)],
#  [('n03218198', 'dogsled', 0.9975001),
#   ('n02100877', 'Irish_setter', 0.0017480669),
#   ('n02109961', 'Eskimo_dog', 0.00014916665),
#   ('n02494079', 'squirrel_monkey', 0.0001371403),
#   ('n02099849', 'Chesapeake_Bay_retriever', 9.077293e-05)],
#  [('n04251144', 'snorkel', 0.8615494),
#   ('n03792782', 'mountain_bike', 0.04298046),
#   ('n02837789', 'bikini', 0.0270612),
#   ('n04371430', 'swimming_trunks', 0.023597684),
#   ('n03255030', 'dumbbell', 0.011503587)],
#  [('n03891251', 'park_bench', 0.9948986),
#   ('n04099969', 'rocking_chair', 0.00076783553),
#   ('n03124170', 'cowboy_hat', 0.0002497254),
#   ('n04604644', 'worm_fence', 0.00021289634),
#   ('n03538406', 'horse_cart', 0.00021089798)],
#  [('n03457902', 'greenhouse', 0.2024455),
#   ('n02788148', 'bannister', 0.13243967),
#   ('n04311004', 'steel_arch_bridge', 0.06740417),
#   ('n03028079', 'church', 0.06634626),
#   ('n04204347', 'shopping_cart', 0.05783769)],
#  [('n02395406', 'hog', 0.9646825),
#   ('n02807133', 'bathing_cap', 0.012481156),
#   ('n07717556', 'butternut_squash', 0.005997492),
#   ('n02364673', 'guinea_pig', 0.0057879654),
#   ('n02786058', 'Band_Aid', 0.0048944973)],
#  [('n09193705', 'alp', 0.32412848),
#   ('n04208210', 'shovel', 0.17116179),
#   ('n04252077', 'snowmobile', 0.10254602),
#   ('n04228054', 'ski', 0.0802425),
#   ('n03792972', 'mountain_tent', 0.07773825)],
#  [('n02097047', 'miniature_schnauzer', 0.8418608),
#   ('n02097209', 'standard_schnauzer', 0.09502916),
#   ('n02091831', 'Saluki', 0.043421175),
#   ('n02110063', 'malamute', 0.010760099),
#   ('n02088094', 'Afghan_hound', 0.0011917123)],
#  [('n02097658', 'silky_terrier', 0.7117578),
#   ('n02094433', 'Yorkshire_terrier', 0.20081334),
#   ('n02096294', 'Australian_terrier', 0.06645619),
#   ('n02097298', 'Scotch_terrier', 0.006649247),
#   ('n03868863', 'oxygen_mask', 0.005731179)],
#  [('n03124170', 'cowboy_hat', 0.9208487),
#   ('n04259630', 'sombrero', 0.04472701),
#   ('n03763968', 'military_uniform', 0.005424582),
#   ('n03595614', 'jersey', 0.005157209),
#   ('n09835506', 'ballplayer', 0.003030074)],
#  [('n02791270', 'barbershop', 0.62673444),
#   ('n04456115', 'torch', 0.12920968),
#   ('n03595614', 'jersey', 0.06527586),
#   ('n03476991', 'hair_spray', 0.014222932),
#   ('n09835506', 'ballplayer', 0.013639951)],
#  [('n04243546', 'slot', 0.9992055),
#   ('n04404412', 'television', 0.00022886637),
#   ('n04152593', 'screen', 0.00019873978),
#   ('n02977058', 'cash_machine', 8.9276116e-05),
#   ('n03782006', 'monitor', 7.478801e-05)],
#  [('n02087394', 'Rhodesian_ridgeback', 0.80881166),
#   ('n02108422', 'bull_mastiff', 0.06947366),
#   ('n02093428', 'American_Staffordshire_terrier', 0.04415993),
#   ('n02108089', 'boxer', 0.038941246),
#   ('n02100583', 'vizsla', 0.013990787)],
#  [('n09428293', 'seashore', 0.36715132),
#   ('n04371430', 'swimming_trunks', 0.26194116),
#   ('n09421951', 'sandbar', 0.23195796),
#   ('n04251144', 'snorkel', 0.040869545),
#   ('n02837789', 'bikini', 0.03995598)],
#  [('n04296562', 'stage', 0.32204455),
#   ('n02883205', 'bow_tie', 0.053364947),
#   ('n04487394', 'trombone', 0.045521665),
#   ('n02992529', 'cellular_telephone', 0.030939238),
#   ('n03110669', 'cornet', 0.025525603)],
#  [('n02096051', 'Airedale', 0.98265195),
#   ('n04540053', 'volleyball', 0.00840521),
#   ('n02106550', 'Rottweiler', 0.0037735791),
#   ('n02802426', 'basketball', 0.0028016907),
#   ('n02095570', 'Lakeland_terrier', 0.0010193216)],
#  [('n04456115', 'torch', 0.42796016),
#   ('n04296562', 'stage', 0.07232343),
#   ('n04370456', 'sweatshirt', 0.038285367),
#   ('n03394916', 'French_horn', 0.032808978),
#   ('n09835506', 'ballplayer', 0.032568157)],
#  [('n02389026', 'sorrel', 0.5053376),
#   ('n02091831', 'Saluki', 0.093534246),
#   ('n02100877', 'Irish_setter', 0.09345302),
#   ('n02480495', 'orangutan', 0.050840974),
#   ('n02111129', 'Leonberg', 0.050391477)],
#  [('n03649909', 'lawn_mower', 0.67552304),
#   ('n04482393', 'tricycle', 0.29520535),
#   ('n03445924', 'golfcart', 0.014408753),
#   ('n03444034', 'go-kart', 0.0136927925),
#   ('n04462240', 'toyshop', 0.0008304238)],
#  [('n03623198', 'knee_pad', 0.5595465),
#   ('n09835506', 'ballplayer', 0.22626594),
#   ('n02916936', 'bulletproof_vest', 0.09831079),
#   ('n03127747', 'crash_helmet', 0.04560355),
#   ('n03763968', 'military_uniform', 0.020027734)],
#  [('n09468604', 'valley', 0.20298657),
#   ('n03733281', 'maze', 0.08214999),
#   ('n03792782', 'mountain_bike', 0.06465203),
#   ('n04326547', 'stone_wall', 0.0605365),
#   ('n03743016', 'megalith', 0.05105742)],
#  [('n02097658', 'silky_terrier', 0.9987986),
#   ('n02094433', 'Yorkshire_terrier', 0.0008396969),
#   ('n02096294', 'Australian_terrier', 0.0003593195),
#   ('n02095570', 'Lakeland_terrier', 3.695879e-07),
#   ('n02097047', 'miniature_schnauzer', 2.9430336e-07)],
#  [('n02091134', 'whippet', 0.73145),
#   ('n02091831', 'Saluki', 0.17560007),
#   ('n02109047', 'Great_Dane', 0.064188145),
#   ('n02087394', 'Rhodesian_ridgeback', 0.021946901),
#   ('n02091244', 'Ibizan_hound', 0.0017904332)],
#  [('n02100877', 'Irish_setter', 0.88242424),
#   ('n02099849', 'Chesapeake_Bay_retriever', 0.08614705),
#   ('n02090379', 'redbone', 0.0188486),
#   ('n02093991', 'Irish_terrier', 0.0020320485),
#   ('n01677366', 'common_iguana', 0.0019280596)],
#  [('n02791270', 'barbershop', 0.39886558),
#   ('n04589890', 'window_screen', 0.06394107),
#   ('n04296562', 'stage', 0.05767838),
#   ('n03032252', 'cinema', 0.054871615),
#   ('n02977058', 'cash_machine', 0.037312146)],
#  [('n04509417', 'unicycle', 0.9999999),
#   ('n02835271', 'bicycle-built-for-two', 7.818014e-08),
#   ('n04482393', 'tricycle', 4.8030707e-08),
#   ('n03792782', 'mountain_bike', 2.6738622e-08),
#   ('n03127747', 'crash_helmet', 5.0631437e-09)],
#  [('n03216828', 'dock', 0.34782794),
#   ('n03447447', 'gondola', 0.11321705),
#   ('n03874293', 'paddlewheel', 0.0823176),
#   ('n02859443', 'boathouse', 0.07339494),
#   ('n03467068', 'guillotine', 0.06245395)],
#  [('n03792782', 'mountain_bike', 0.5991718),
#   ('n03538406', 'horse_cart', 0.10000312),
#   ('n02841315', 'binoculars', 0.06963768),
#   ('n04509417', 'unicycle', 0.03236603),
#   ('n03868242', 'oxcart', 0.028745592)],
#  [('n03670208', 'limousine', 0.18532449),
#   ('n03796401', 'moving_van', 0.10033644),
#   ('n06359193', 'web_site', 0.069794774),
#   ('n03770679', 'minivan', 0.054357),
#   ('n03769881', 'minibus', 0.047229428)],
#  [('n04336792', 'stretcher', 0.9470905),
#   ('n02797295', 'barrow', 0.014658853),
#   ('n03891251', 'park_bench', 0.011685262),
#   ('n03457902', 'greenhouse', 0.007798366),
#   ('n04371774', 'swing', 0.0021353099)],
#  [('n02100583', 'vizsla', 0.9819126),
#   ('n02090379', 'redbone', 0.017359965),
#   ('n02087394', 'Rhodesian_ridgeback', 0.00045656055),
#   ('n02088466', 'bloodhound', 0.00024726416),
#   ('n02100877', 'Irish_setter', 1.73046e-05)],
#  [('n04613696', 'yurt', 0.13265142),
#   ('n04456115', 'torch', 0.12874636),
#   ('n07615774', 'ice_lolly', 0.10987716),
#   ('n04228054', 'ski', 0.09265067),
#   ('n02948072', 'candle', 0.07136811)],
#  [('n04296562', 'stage', 0.32638264),
#   ('n04584207', 'wig', 0.25320044),
#   ('n03733131', 'maypole', 0.100951426),
#   ('n03724870', 'mask', 0.036308527),
#   ('n03770439', 'miniskirt', 0.032262906)],
#  [('n04486054', 'triumphal_arch', 0.17136195),
#   ('n03788195', 'mosque', 0.11673941),
#   ('n03028079', 'church', 0.07683796),
#   ('n02825657', 'bell_cote', 0.07261626),
#   ('n04228054', 'ski', 0.057210255)],
#  [('n03670208', 'limousine', 0.39630878),
#   ('n02894605', 'breakwater', 0.1929378),
#   ('n03769881', 'minibus', 0.06720629),
#   ('n04347754', 'submarine', 0.04259282),
#   ('n02917067', 'bullet_train', 0.026344875)],
#  [('n09246464', 'cliff', 0.9861937),
#   ('n03042490', 'cliff_dwelling', 0.009450994),
#   ('n09468604', 'valley', 0.0030733817),
#   ('n09399592', 'promontory', 0.00041807693),
#   ('n03160309', 'dam', 0.00028304124)],
#  [('n03874293', 'paddlewheel', 0.37262625),
#   ('n03344393', 'fireboat', 0.21518986),
#   ('n03673027', 'liner', 0.17212892),
#   ('n03216828', 'dock', 0.094547875),
#   ('n04273569', 'speedboat', 0.029413305)],
#  [('n03617480', 'kimono', 0.14557554),
#   ('n04507155', 'umbrella', 0.13062972),
#   ('n03877472', 'pajama', 0.11972199),
#   ('n03535780', 'horizontal_bar', 0.08515029),
#   ('n04136333', 'sarong', 0.061936956)],
#  [('n04371774', 'swing', 0.9999988),
#   ('n03995372', 'power_drill', 4.8087884e-07),
#   ('n04067472', 'reel', 4.23788e-07),
#   ('n04039381', 'racket', 5.2264323e-08),
#   ('n03017168', 'chime', 3.2541717e-08)],
#  [('n07615774', 'ice_lolly', 0.40155768),
#   ('n03494278', 'harmonica', 0.39788103),
#   ('n02786058', 'Band_Aid', 0.07634414),
#   ('n03825788', 'nipple', 0.021805707),
#   ('n04357314', 'sunscreen', 0.017139181)],
#  [('n04367480', 'swab', 0.59302205),
#   ('n03141823', 'crutch', 0.2302935),
#   ('n04507155', 'umbrella', 0.051222887),
#   ('n03970156', 'plunger', 0.0360594),
#   ('n04286575', 'spotlight', 0.027616896)],
#  [('n02097130', 'giant_schnauzer', 0.61260074),
#   ('n02133161', 'American_black_bear', 0.14345355),
#   ('n02099267', 'flat-coated_retriever', 0.07345564),
#   ('n02106550', 'Rottweiler', 0.03986602),
#   ('n02107574', 'Greater_Swiss_Mountain_dog', 0.024151776)],
#  [('n02091244', 'Ibizan_hound', 0.45844728),
#   ('n02422699', 'impala', 0.20046498),
#   ('n02100583', 'vizsla', 0.072752975),
#   ('n02105162', 'malinois', 0.058564566),
#   ('n02087394', 'Rhodesian_ridgeback', 0.0491681)],
#  [('n04482393', 'tricycle', 0.77796566),
#   ('n07615774', 'ice_lolly', 0.047595263),
#   ('n04099969', 'rocking_chair', 0.038728196),
#   ('n03942813', 'ping-pong_ball', 0.028237661),
#   ('n04371774', 'swing', 0.020747153)],
#  [('n07615774', 'ice_lolly', 0.4445531),
#   ('n04371774', 'swing', 0.3109652),
#   ('n03944341', 'pinwheel', 0.032293703),
#   ('n02966193', 'carousel', 0.020456992),
#   ('n04482393', 'tricycle', 0.019001229)],
#  [('n03538406', 'horse_cart', 0.99202746),
#   ('n02389026', 'sorrel', 0.0069131935),
#   ('n02437312', 'Arabian_camel', 0.0005018639),
#   ('n03967562', 'plow', 0.00045964634),
#   ('n02795169', 'barrel', 2.646515e-05)],
#  [('n03355925', 'flagpole', 0.5513469),
#   ('n03983396', 'pop_bottle', 0.074959174),
#   ('n04476259', 'tray', 0.054238092),
#   ('n02823750', 'beer_glass', 0.039020393),
#   ('n04209133', 'shower_cap', 0.013411747)],
#  [('n04209133', 'shower_cap', 0.9972145),
#   ('n04251144', 'snorkel', 0.00067073124),
#   ('n03424325', 'gasmask', 0.00058610324),
#   ('n02807133', 'bathing_cap', 0.000410665),
#   ('n03127747', 'crash_helmet', 0.00013546472)],
#  [('n03791053', 'motor_scooter', 0.07935434),
#   ('n09229709', 'bubble', 0.06755637),
#   ('n02971356', 'carton', 0.054641325),
#   ('n04590129', 'window_shade', 0.054209333),
#   ('n04201297', 'shoji', 0.04022196)],
#  [('n04456115', 'torch', 0.6126281),
#   ('n04259630', 'sombrero', 0.26981753),
#   ('n03124170', 'cowboy_hat', 0.036621086),
#   ('n04039381', 'racket', 0.03283685),
#   ('n04355933', 'sunglass', 0.016473334)],
#  [('n02077923', 'sea_lion', 0.25973326),
#   ('n03891251', 'park_bench', 0.15996163),
#   ('n09421951', 'sandbar', 0.1262592),
#   ('n04493381', 'tub', 0.11689367),
#   ('n02807133', 'bathing_cap', 0.04609791)],
#  [('n04371430', 'swimming_trunks', 0.8203803),
#   ('n02807133', 'bathing_cap', 0.09774191),
#   ('n09421951', 'sandbar', 0.035397444),
#   ('n04251144', 'snorkel', 0.018534744),
#   ('n04493381', 'tub', 0.0058177887)],
#  [('n03733131', 'maypole', 0.47942832),
#   ('n04579432', 'whistle', 0.11380321),
#   ('n03372029', 'flute', 0.08435194),
#   ('n04456115', 'torch', 0.051475994),
#   ('n09229709', 'bubble', 0.045177482)],
#  [('n02091244', 'Ibizan_hound', 0.47766656),
#   ('n02109047', 'Great_Dane', 0.1675474),
#   ('n02092339', 'Weimaraner', 0.15143839),
#   ('n02093428', 'American_Staffordshire_terrier', 0.12812072),
#   ('n02087394', 'Rhodesian_ridgeback', 0.020914754)],
#  [('n04118538', 'rugby_ball', 0.90203065),
#   ('n09835506', 'ballplayer', 0.012848064),
#   ('n03379051', 'football_helmet', 0.011953411),
#   ('n04254680', 'soccer_ball', 0.010377262),
#   ('n02799071', 'baseball', 0.0067218994)],
#  [('n02091831', 'Saluki', 0.54275435),
#   ('n02091134', 'whippet', 0.2847744),
#   ('n09835506', 'ballplayer', 0.04590936),
#   ('n02007558', 'flamingo', 0.023182034),
#   ('n02799071', 'baseball', 0.02184384)],
#  [('n02437312', 'Arabian_camel', 0.9330177),
#   ('n02129165', 'lion', 0.023605738),
#   ('n02087394', 'Rhodesian_ridgeback', 0.010990155),
#   ('n02091831', 'Saluki', 0.0040155654),
#   ('n02091134', 'whippet', 0.0030813755)]]

# %%
image_index = 9

img = np.array(batch[image_index] * 255, dtype=np.uint8)

image = PIL.Image.fromarray(img)
image.show()
